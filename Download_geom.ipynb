# %%
#Programma per scaricare tutti i file geom

import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import os

url = "https://pds-geosciences.wustl.edu/mro/mro-m-sharad-5-radargram-v1/mrosh_2001/data/geom/"
response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

path='geom'




for i in range(284,len(soup.findAll('a'))):
    #soup.findAll('a')
    one_a_tag = soup.findAll('a')[i]
    link = one_a_tag['href']
    
    url = 'https://pds-geosciences.wustl.edu'+ link
    print(url)
    response = requests.get(url)

    soup1 = BeautifulSoup(response.text, "html.parser")

    for j in range(1, len(soup1.findAll('a'))):
        one_a_tag1 = soup1.findAll('a')[j]
        link1 = one_a_tag1['href']
        url1 = 'https://pds-geosciences.wustl.edu'+ link1
        download_url = 'https://pds-geosciences.wustl.edu'+ link1
        #print(download_url)
        
    #print(type(link))

        fullfilename= os.path.join(path, link1[-19:])
    
    #download_url = 'https://pds-geosciences.wustl.edu'+ link
    
        urllib.request.urlretrieve(download_url, fullfilename)
# Out:
# https://pds-geosciences.wustl.edu/mro/mro-m-sharad-5-radargram-v1/mrosh_2001/data/geom/s_0374xx/
# https://pds-geosciences.wustl.edu/mro/mro-m-sharad-5-radargram-v1/mrosh_2001/data/geom/s_0375xx/
# https://pds-geosciences.wustl.edu/mro/mro-m-sharad-5-radargram-v1/mrosh_2001/data/geom/s_0376xx/
# https://pds-geosciences.wustl.edu/mro/mro-m-sharad-5-radargram-v1/mrosh_2001/data/geom/s_0377xx/
# https://pds-geosciences.wustl.edu/mro/mro-m-sharad-5-radargram-v1/mrosh_2001/data/geom/s_0378xx/
# https://pds-geosciences.wustl.edu/mro/mro-m-sharad-5-radargram-v1/mrosh_2001/data/geom/s_0379xx/
# https://pds-geosciences.wustl.edu/mro/mro-m-sharad-5-radargram-v1/mrosh_2001/data/geom/s_0380xx/
# https://pds-geosciences.wustl.edu/mro/mro-m-sharad-5-radargram-v1/mrosh_2001/data/geom/s_0381xx/
# https://pds-geosciences.wustl.edu/mro/mro-m-sharad-5-radargram-v1/mrosh_2001/data/geom/s_0382xx/
# https://pds-geosciences.wustl.edu/mro/mro-m-sharad-5-radargram-v1/mrosh_2001/data/geom/s_0383xx/
# ...

# %%
import urllib.parse
path = urllib.parse.urlparse("https://pds-geosciences.wustl.edu/mro/mro-m-sharad-5-radargram-v1/mrosh_2001/data/geom/").path
print(path)

import os.path
os.path.split(path)
while os.path.dirname(path) != '/':
     path = os.path.dirname(path)
     print(path)
